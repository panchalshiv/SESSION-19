# %%
class Song:
    def __init__(self, title, artist, duration):
        self.title = title
        self.artist = artist
        self.duration = duration


# Creating an object
song1 = Song("Tum Hi Ho", "Arijit Singh", 262)

print(song1.title)
print(song1.artist)
print(song1.duration)
# Out:
# Tum Hi Ho
# Arijit Singh
# 262

# %%
class Song:
    def __init__(self, title, artist, duration):
        self.title = title
        self.artist = artist
        self.duration = duration


# Favorite Spotify song
my_song = Song("Tum Hi Ho", "Arijit Singh", 262)

print("Title:", my_song.title)
print("Artist:", my_song.artist)
# Out:
# Title: Tum Hi Ho
# Artist: Arijit Singh

# %%
class Song:
    def __init__(self, title, artist, duration):
        self.title = title
        self.artist = artist
        self.duration = duration

    def play_preview(self):
        print(f"Playing 30-second preview of {self.title} by {self.artist}")


my_song = Song("Tum Hi Ho", "Arijit Singh", 262)

my_song.play_preview()
# Out:
# Playing 30-second preview of Tum Hi Ho by Arijit Singh

# %%
class FoodOrder:
    def __init__(self, restaurant_name):
        self.restaurant_name = restaurant_name
        self.items = []
        self.total_price = 0

    def add_item(self, item, price):
        self.items.append(item)
        self.total_price += price


# Creating a food order
order = FoodOrder("Zomato Restaurant")

order.add_item("Pizza", 299)
order.add_item("Burger", 149)

print("Restaurant:", order.restaurant_name)
print("Items:", order.items)
print("Total Price:", order.total_price)
# Out:
# Restaurant: Zomato Restaurant
# Items: ['Pizza', 'Burger']
# Total Price: 448

# %%
class Song:
    def __init__(self, title, artist, duration):
        self.title = title
        self.artist = artist
        self.duration = duration
        self.play_count = 0

    def increment_play_count(self):
        self.play_count += 1


# Creating a Song object
my_song = Song("Tum Hi Ho", "Arijit Singh", 262)

# Playing the song 3 times
my_song.increment_play_count()
my_song.increment_play_count()
my_song.increment_play_count()

print("Song:", my_song.title)
print("Play Count:", my_song.play_count)
# Out:
# Song: Tum Hi Ho
# Play Count: 3
